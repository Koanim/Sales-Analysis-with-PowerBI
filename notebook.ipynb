# %%
import pyodbc
from dotenv import load_dotenv
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

load_dotenv()
server = os.getenv('SERVER')
database = os.getenv('DATABASE')
user = os.getenv('USER')
password = os.getenv('PASSWORD')

# %%
# Create a connection string
connection_string = f"DRIVER={{ODBC Driver 18 for SQL Server}};SERVER={server};DATABASE={database};UID={user};PWD={password};MARS_Connection=yes;MinProtocolVersion=TLSv1.2;"

# %%
connection = pyodbc.connect(connection_string)

# %%
query1 = "SELECT * FROM dbo.Sales_July_2019"

july_df = pd.read_sql(query1, connection)

query2 = "SELECT * FROM dbo.Sales_August_2019"

august_df = pd.read_sql(query2, connection)

query3 = "SELECT * FROM dbo.Sales_September_2019"

september_df = pd.read_sql(query3, connection)

query4 = "SELECT * FROM dbo.Sales_October_2019"

october_df = pd.read_sql(query4, connection)

query5 = "SELECT * FROM dbo.Sales_November_2019"

november_df = pd.read_sql(query5, connection)

query6 = "SELECT * FROM dbo.Sales_December_2019"

december_df = pd.read_sql(query6, connection)

# %%
july_df.head()
# Out:
#    Order_ID                   Product  Quantity_Ordered  Price_Each  \
# 0  222910.0  Apple Airpods Headphones               1.0      150.00
# 1  222911.0             Flatscreen TV               1.0      300.00
# 2  222912.0     AA Batteries (4-pack)               1.0        3.84
# 3  222913.0     AA Batteries (4-pack)               1.0        3.84
# 4  222914.0    AAA Batteries (4-pack)               5.0        2.99
#
#            Order_Date                  Purchase_Address
# 0 2026-07-19 16:51:00   389 South St, Atlanta, GA 30301
# 1 2005-07-19 08:55:00     590 4th St, Seattle, WA 98101
# 2 2029-07-19 12:41:00    861 Hill St, Atlanta, GA 30301
# 3 2028-07-19 10:15:00   190 Ridge St, Atlanta, GA 30301
# 4 2031-07-19 02:13:00  824 Forest St, Seattle, WA 98101

# %%
july_df.to_csv('./Data/july_df.csv', index=False)
august_df.to_csv('./Data/august_df.csv', index=False)
september_df.to_csv('./Data/september_df.csv', index=False)
october_df.to_csv('./Data/october_df.csv', index=False)
november_df.to_csv('./Data/november_df.csv', index=False)
december_df.to_csv('./Data/december_df.csv', index=False)

# %%
jan_df = pd.read_csv('./Data/Sales_January_2019.csv')
feb_df = pd.read_csv('./Data/Sales_February_2019.csv')
mar_df = pd.read_csv('./Data/Sales_March_2019.csv')
apr_df = pd.read_csv('./Data/Sales_April_2019.csv')
may_df = pd.read_csv('./Data/Sales_May_2019.csv')
jun_df = pd.read_csv('./Data/Sales_June_2019.csv')
jul_df = pd.read_csv('./Data/july_df.csv')
aug_df = pd.read_csv('./Data/august_df.csv')
sep_df = pd.read_csv('./Data/september_df.csv')
oct_df = pd.read_csv('./Data/october_df.csv')
nov_df = pd.read_csv('./Data/november_df.csv')
dec_df = pd.read_csv('./Data/december_df.csv')

# %%
jan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9723 entries, 0 to 9722
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          9697 non-null   object
#  1   Product           9697 non-null   object
#  2   Quantity Ordered  9697 non-null   object
#  3   Price Each        9697 non-null   object
#  4   Order Date        9697 non-null   object
#  5   Purchase Address  9697 non-null   object
# dtypes: object(6)
# memory usage: 455.9+ KB

# %%
feb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12036 entries, 0 to 12035
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          12004 non-null  object
#  1   Product           12004 non-null  object
#  2   Quantity Ordered  12004 non-null  object
#  3   Price Each        12004 non-null  object
#  4   Order Date        12004 non-null  object
#  5   Purchase Address  12004 non-null  object
# dtypes: object(6)
# memory usage: 564.3+ KB

# %%
mar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15226 entries, 0 to 15225
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          15189 non-null  object
#  1   Product           15189 non-null  object
#  2   Quantity Ordered  15189 non-null  object
#  3   Price Each        15189 non-null  object
#  4   Order Date        15189 non-null  object
#  5   Purchase Address  15189 non-null  object
# dtypes: object(6)
# memory usage: 713.8+ KB

# %%
apr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18383 entries, 0 to 18382
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          18324 non-null  object
#  1   Product           18324 non-null  object
#  2   Quantity Ordered  18324 non-null  object
#  3   Price Each        18324 non-null  object
#  4   Order Date        18324 non-null  object
#  5   Purchase Address  18324 non-null  object
# dtypes: object(6)
# memory usage: 861.8+ KB

# %%
may_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16635 entries, 0 to 16634
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          16587 non-null  object
#  1   Product           16587 non-null  object
#  2   Quantity Ordered  16587 non-null  object
#  3   Price Each        16587 non-null  object
#  4   Order Date        16587 non-null  object
#  5   Purchase Address  16587 non-null  object
# dtypes: object(6)
# memory usage: 779.9+ KB

# %%
jun_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13622 entries, 0 to 13621
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          13579 non-null  object
#  1   Product           13579 non-null  object
#  2   Quantity Ordered  13579 non-null  object
#  3   Price Each        13579 non-null  object
#  4   Order Date        13579 non-null  object
#  5   Purchase Address  13579 non-null  object
# dtypes: object(6)
# memory usage: 638.7+ KB

# %%
jul_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14371 entries, 0 to 14370
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          14291 non-null  float64
#  1   Product           14326 non-null  object
#  2   Quantity_Ordered  14291 non-null  float64
#  3   Price_Each        14291 non-null  float64
#  4   Order_Date        14291 non-null  object
#  5   Purchase_Address  14326 non-null  object
# dtypes: float64(3), object(3)
# memory usage: 673.8+ KB

# %%
first_half_sales_df = pd.concat([jan_df, feb_df, mar_df, apr_df, may_df, jun_df], axis=0)

# %%
first_half_sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85625 entries, 0 to 13621
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          85380 non-null  object
#  1   Product           85380 non-null  object
#  2   Quantity Ordered  85380 non-null  object
#  3   Price Each        85380 non-null  object
#  4   Order Date        85380 non-null  object
#  5   Purchase Address  85380 non-null  object
# dtypes: object(6)
# memory usage: 4.6+ MB

# %%
first_half_sales_df.head(20)
# Out:
#    Order ID                     Product Quantity Ordered Price Each  \
# 0    141234                      iPhone                1        700
# 1    141235    Lightning Charging Cable                1      14.95
# 2    141236            Wired Headphones                2      11.99
# 3    141237            27in FHD Monitor                1     149.99
# 4    141238            Wired Headphones                1      11.99
# 5    141239      AAA Batteries (4-pack)                1       2.99
# 6    141240      27in 4K Gaming Monitor                1     389.99
# 7    141241        USB-C Charging Cable                1      11.95
# 8    141242  Bose SoundSport Headphones                1      99.99
# 9    141243    Apple Airpods Headphones                1        150
# 10   141244    Apple Airpods Headphones                1        150
# 11   141245          Macbook Pro Laptop                1       1700
# 12   141246      AAA Batteries (4-pack)                3       2.99
# ...

# %%
first_half_sales_df['Quantity Ordered'].iloc[1073]
# Out:
# 'Quantity Ordered'

# %%
remove = first_half_sales_df[first_half_sales_df['Quantity Ordered']=='Quantity Ordered']

# %%
first_half_sales_df = first_half_sales_df.drop(remove.index)

# %%
first_half_sales_df['Quantity Ordered'] = pd.to_numeric(first_half_sales_df['Quantity Ordered'])
first_half_sales_df['Price Each'] = pd.to_numeric(first_half_sales_df['Price Each'])

# %%
first_half_sales_df['Order Date'] = pd.to_datetime(first_half_sales_df['Order Date'])

# %%
first_half_sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 84771 entries, 0 to 13621
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          84527 non-null  object
#  1   Product           84527 non-null  object
#  2   Quantity Ordered  84527 non-null  float64
#  3   Price Each        84527 non-null  float64
#  4   Order Date        84527 non-null  datetime64[ns]
#  5   Purchase Address  84527 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(3)
# memory usage: 4.5+ MB

# %%
first_half_sales_df.head(30)
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    141234                      iPhone               1.0      700.00
# 1    141235    Lightning Charging Cable               1.0       14.95
# 2    141236            Wired Headphones               2.0       11.99
# 3    141237            27in FHD Monitor               1.0      149.99
# 4    141238            Wired Headphones               1.0       11.99
# 5    141239      AAA Batteries (4-pack)               1.0        2.99
# 6    141240      27in 4K Gaming Monitor               1.0      389.99
# 7    141241        USB-C Charging Cable               1.0       11.95
# 8    141242  Bose SoundSport Headphones               1.0       99.99
# 9    141243    Apple Airpods Headphones               1.0      150.00
# 10   141244    Apple Airpods Headphones               1.0      150.00
# 11   141245          Macbook Pro Laptop               1.0     1700.00
# ...

# %%
second_half_sales_df = pd.concat([jul_df, aug_df, sep_df, oct_df, nov_df, dec_df], axis=0)

# %%
second_half_sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101225 entries, 0 to 25116
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order_ID          100730 non-null  float64
#  1   Product           100925 non-null  object
#  2   Quantity_Ordered  100730 non-null  float64
#  3   Price_Each        100730 non-null  float64
#  4   Order_Date        100730 non-null  object
#  5   Purchase_Address  100925 non-null  object
# dtypes: float64(3), object(3)
# memory usage: 5.4+ MB

# %%
second_half_sales_df['Order_ID'] = second_half_sales_df['Order_ID'].astype(str)

# %%
#second_half_sales_df['Order_Date'] = pd.to_datetime(second_half_sales_df['Order_Date'])

# %%
second_half_sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101225 entries, 0 to 25116
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order_ID          101225 non-null  object
#  1   Product           100925 non-null  object
#  2   Quantity_Ordered  100730 non-null  float64
#  3   Price_Each        100730 non-null  float64
#  4   Order_Date        100730 non-null  object
#  5   Purchase_Address  100925 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 5.4+ MB

# %%
second_half_sales_df.head()
# Out:
#    Order_ID                   Product  Quantity_Ordered  Price_Each  \
# 0  222910.0  Apple Airpods Headphones               1.0      150.00
# 1  222911.0             Flatscreen TV               1.0      300.00
# 2  222912.0     AA Batteries (4-pack)               1.0        3.84
# 3  222913.0     AA Batteries (4-pack)               1.0        3.84
# 4  222914.0    AAA Batteries (4-pack)               5.0        2.99
#
#             Order_Date                  Purchase_Address
# 0  2026-07-19 16:51:00   389 South St, Atlanta, GA 30301
# 1  2005-07-19 08:55:00     590 4th St, Seattle, WA 98101
# 2  2029-07-19 12:41:00    861 Hill St, Atlanta, GA 30301
# 3  2028-07-19 10:15:00   190 Ridge St, Atlanta, GA 30301
# 4  2031-07-19 02:13:00  824 Forest St, Seattle, WA 98101

# %%
second_half_sales_df['Order_Date'] = second_half_sales_df['Order_Date'].str[2:]

# %%
second_half_sales_df.head(10)
# Out:
#    Order_ID                     Product  Quantity_Ordered  Price_Each  \
# 0  222910.0    Apple Airpods Headphones               1.0  150.000000
# 1  222911.0               Flatscreen TV               1.0  300.000000
# 2  222912.0       AA Batteries (4-pack)               1.0    3.840000
# 3  222913.0       AA Batteries (4-pack)               1.0    3.840000
# 4  222914.0      AAA Batteries (4-pack)               5.0    2.990000
# 5  222915.0  Bose SoundSport Headphones               1.0   99.989998
# 6  222916.0                Google Phone               1.0  600.000000
# 7  222917.0                    LG Dryer               1.0  600.000000
# 8  222918.0        USB-C Charging Cable               1.0   11.950000
# 9  222919.0    Lightning Charging Cable               1.0   14.950000
#
#           Order_Date                          Purchase_Address
# 0  26-07-19 16:51:00           389 South St, Atlanta, GA 30301
# 1  05-07-19 08:55:00             590 4th St, Seattle, WA 98101
# ...

# %%
second_half_sales_df['Order_Date'] = pd.to_datetime(second_half_sales_df['Order_Date'])

# %%
second_half_sales_df = second_half_sales_df.rename(columns={'Order_ID': 'Order ID'})
second_half_sales_df = second_half_sales_df.rename(columns={'Quantity_Ordered': 'Quantity Ordered'})
second_half_sales_df = second_half_sales_df.rename(columns={'Price_Each': 'Price Each'})
second_half_sales_df = second_half_sales_df.rename(columns={'Purchase_Address': 'Purchase Address'})
second_half_sales_df = second_half_sales_df.rename(columns={'Order_Date': 'Order Date'})

# %%
second_half_sales_df.head()
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 0  222910.0  Apple Airpods Headphones               1.0      150.00
# 1  222911.0             Flatscreen TV               1.0      300.00
# 2  222912.0     AA Batteries (4-pack)               1.0        3.84
# 3  222913.0     AA Batteries (4-pack)               1.0        3.84
# 4  222914.0    AAA Batteries (4-pack)               5.0        2.99
#
#            Order Date                  Purchase Address
# 0 2019-07-26 16:51:00   389 South St, Atlanta, GA 30301
# 1 2019-05-07 08:55:00     590 4th St, Seattle, WA 98101
# 2 2019-07-29 12:41:00    861 Hill St, Atlanta, GA 30301
# 3 2019-07-28 10:15:00   190 Ridge St, Atlanta, GA 30301
# 4 2019-07-31 02:13:00  824 Forest St, Seattle, WA 98101

# %%
sales_df = pd.concat([first_half_sales_df, second_half_sales_df], axis=0)
sales_df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone               1.0      700.00
# 1   141235  Lightning Charging Cable               1.0       14.95
# 2   141236          Wired Headphones               2.0       11.99
# 3   141237          27in FHD Monitor               1.0      149.99
# 4   141238          Wired Headphones               1.0       11.99
#
#            Order Date                       Purchase Address
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185996 entries, 0 to 25116
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185752 non-null  object
#  1   Product           185452 non-null  object
#  2   Quantity Ordered  185257 non-null  float64
#  3   Price Each        185257 non-null  float64
#  4   Order Date        185257 non-null  datetime64[ns]
#  5   Purchase Address  185452 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(3)
# memory usage: 9.9+ MB

# %%
sales_df.describe(include='all').T
# Out:
#                      count  unique                   top   freq  \
# Order ID            185752  177797                   nan    495
# Product             185452      20  USB-C Charging Cable  21827
# Quantity Ordered  185257.0     NaN                   NaN    NaN
# Price Each        185257.0     NaN                   NaN    NaN
# Order Date          185257     NaN                   NaN    NaN
# Purchase Address    185452  140414      Purchase Address    195
#
#                                            mean                  min  \
# Order ID                                    NaN                  NaN
# Product                                     NaN                  NaN
# Quantity Ordered                       1.124254                  1.0
# Price Each                           184.414985                 2.99
# Order Date        2019-06-28 07:32:04.536184832  2019-01-01 03:07:00
# Purchase Address                            NaN                  NaN
#
# ...

# %%
sales_df.isna().sum()
# Out:
# Order ID            244
# Product             544
# Quantity Ordered    739
# Price Each          739
# Order Date          739
# Purchase Address    544
# dtype: int64

# %%
sales_df.duplicated().sum()
# Out:
# np.int64(998)

# %%
sales_df = sales_df.drop_duplicates()

# %%
sales_df.isna().sum()
# Out:
# Order ID            1
# Product             2
# Quantity Ordered    3
# Price Each          3
# Order Date          3
# Purchase Address    2
# dtype: int64

# %%
null_df = sales_df[sales_df.isna().any(axis=1)]
null_df
# Out:
#     Order ID  Product  Quantity Ordered  Price Each Order Date  \
# 664      NaN      NaN               NaN         NaN        NaT
# 199      nan      NaN               NaN         NaN        NaT
# 775      nan  Product               NaN         NaN        NaT
#
#      Purchase Address
# 664               NaN
# 199               NaN
# 775  Purchase Address

# %%
sales_df = sales_df.drop([null_df.index[0], null_df.index[1], null_df.index[2]])

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 184962 entries, 0 to 25116
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          184962 non-null  object
#  1   Product           184962 non-null  object
#  2   Quantity Ordered  184962 non-null  float64
#  3   Price Each        184962 non-null  float64
#  4   Order Date        184962 non-null  datetime64[ns]
#  5   Purchase Address  184962 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(3)
# memory usage: 9.9+ MB

# %%
#sales_df[['Street', 'City', 'ZIP']] = sales_df['Purchase Address'].str.extract(r'^(.*),\s*(.*),\s*(\d{5})$')

sales_df[['Street', 'City', 'ZIP']] = sales_df['Purchase Address'].str.extract(r'^(.*?),\s*(.*?),\s*\w{2}\s*(\d{5})$')

# %%
sales_df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone               1.0      700.00
# 1   141235  Lightning Charging Cable               1.0       14.95
# 2   141236          Wired Headphones               2.0       11.99
# 3   141237          27in FHD Monitor               1.0      149.99
# 4   141238          Wired Headphones               1.0       11.99
#
#            Order Date                       Purchase Address         Street  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215  944 Walnut St
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035   185 Maple St
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016   538 Adams St
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001    738 10th St
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301    387 10th St
#
#             City    ZIP
# 0         Boston  02215
# 1       Portland  97035
# 2  San Francisco  94016
# ...

# %%
sales_df.to_csv('./Data/sales_df.csv', index=False)

# %% [markdown]
# ## EDA

# %%
numcols = sales_df.select_dtypes(['float', 'int']).columns

catcols = sales_df.select_dtypes(['object']).columns
datecols = sales_df.select_dtypes(['datetime64']).columns

print(f'{numcols}\n{catcols}\n{datecols}')
# Out:
# Index(['Quantity Ordered', 'Price Each'], dtype='object')
# Index(['Order ID', 'Product', 'Purchase Address', 'Street', 'City', 'ZIP'], dtype='object')
# Index(['Order Date'], dtype='object')

# %%
sales_df[numcols].hist(figsize=(10,5))
plt.show()

# %%
#obj_cols = sales_df.select_dtypes(['object']).columns
plt.figure(figsize=(10, 5))

for i, variable in enumerate(numcols):
    plt.subplot(3,2, i + 1)
    sns.histplot(sales_df,x=sales_df[variable], stat='frequency')
    plt.tight_layout(pad=3)
    plt.xticks(rotation=45)

# %%
sns.catplot(sales_df, x='Product', y='Price Each', kind='bar')
plt.xticks(rotation=90)  
plt.show()

# %% [markdown]
# sales_df[['Street', 'City', 'ZIP']] = sales_df['Purchase Address'].str.extract(r'^(.*),\s*(.*),\s*(\d{5})$')
